# %% [markdown]
# # Импорт

# %%
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.gridspec as gridspec

# %% [markdown]
# # Загрузка Датасета

# %%
df_ter = pd.concat([pd.read_csv(i).drop('year', axis=1)
                    .drop('Unnamed: 0', axis=1)
                    .apply(lambda s: s.map(lambda a: float(a.replace(',', '.')) 
                                           if type(a) is str 
                                           else a)) 
                    for i in glob.glob("..\\..\\DATA\\Ters\\*")])
df_ter
# Out:
#     Доходы гостиниц и аналогичных средств размещения  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 12                                         908662.89
# 13                                        1005690.20
# 14                                        1001489.70
# 15                                        1116225.60
# 16                                        1388261.40
#
#     Число гостиниц и средств размещения  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# ...

# %%
df_ter.drop('Индекс стоимости жизни', axis=1).dropna()
# Out:
#     Доходы гостиниц и аналогичных средств размещения  \
# 8                                          847640.30
# 9                                          927587.90
# 10                                         888997.70
# 11                                         927467.70
# 12                                         906521.70
# ..                                               ...
# 8                                          826791.30
# 9                                          942051.00
# 10                                         905200.60
# 11                                         871948.10
# 12                                         908662.89
#
#     Число гостиниц и средств размещения  \
# 8                                 167.0
# 9                                 202.0
# 10                                200.0
# 11                                188.0
# 12                                233.0
# ..                                  ...
# ...

# %%
df_ter.drop('Индекс стоимости жизни', axis=1).to_csv(
    '../../DATA/Concatination_of_ters/Without_Индекс стоимости жизни/with_nan.csv')
df_ter.drop('Индекс стоимости жизни', axis=1).dropna().to_csv(
    '../../DATA/Concatination_of_ters/Without_Индекс стоимости жизни/without_nan.csv')
