# %% [markdown]
# # Импорт

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.gridspec as gridspec

# %% [markdown]
# # Загрузка Датасета

# %%
data = pd.read_csv('../../DATA/Split/Число гостиниц и средств размещения.csv').drop('Unnamed: 0', axis=1)

# %%
data.columns.to_numpy().shape
# Out:
# (15,)

# %% [markdown]
# # Графики "Коробка с усами"

# %%
data = data.apply(lambda s: s.map(lambda a: float(a.replace(',', '.')) if type(a) is str else a))
names = data.columns.to_numpy()[1:]

# %%
fig = plt.figure(tight_layout=True)
fig.set_figheight(25)
fig.set_figwidth(25)
gs = gridspec.GridSpec(7, 2)
for i in range(7):
    for j in range(2):
        ax = fig.add_subplot(gs[i, j])
        ax.boxplot(data[names[i+j]].dropna())
        ax.set_title(names[i+j])
